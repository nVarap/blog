# %% [markdown]
# # API Hacks
# > Error Management
# - toc: true
# - comments: true
# - permalink: /Hacks/apihacks
# - categories: [Hacks]
# - tags: [Week 7]
# - image: images/pythonlogo.png

# %%
import requests
import json

url = "https://corona-virus-world-and-india-data.p.rapidapi.com/api_india_timeline"

headers = {
	"X-RapidAPI-Key": "721c8e8789msh4f6199095fcff35p13f037jsnc1e7998c8457",
	"X-RapidAPI-Host": "corona-virus-world-and-india-data.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)
jsonr = response.json()

print(jsonr)

for r in jsonr:
    if r['dailyconfirmed']== '1':
        print('worlde')
# Out:
# [{'dailyconfirmed': '1', 'dailydeceased': '0', 'dailyrecovered': '0', 'date': '30 January 2020', 'dateymd': '2020-01-30', 'totalconfirmed': '1', 'totaldeceased': '0', 'totalrecovered': '0'}, {'dailyconfirmed': '0', 'dailydeceased': '0', 'dailyrecovered': '0', 'date': '31 January 2020', 'dateymd': '2020-01-31', 'totalconfirmed': '1', 'totaldeceased': '0', 'totalrecovered': '0'}, {'dailyconfirmed': '0', 'dailydeceased': '0', 'dailyrecovered': '0', 'date': '1 February 2020', 'dateymd': '2020-02-01', 'totalconfirmed': '1', 'totaldeceased': '0', 'totalrecovered': '0'}, {'dailyconfirmed': '1', 'dailydeceased': '0', 'dailyrecovered': '0', 'date': '2 February 2020', 'dateymd': '2020-02-02', 'totalconfirmed': '2', 'totaldeceased': '0', 'totalrecovered': '0'}, {'dailyconfirmed': '1', 'dailydeceased': '0', 'dailyrecovered': '0', 'date': '3 February 2020', 'dateymd': '2020-02-03', 'totalconfirmed': '3', 'totaldeceased': '0', 'totalrecovered': '0'}, {'dailyconfirmed': '0', 'dailydeceased': '0', '
# ...

# %% [markdown]
# # Hacks
# - I used the NBA API to allow the user to get the stats of certain players in certain seasons
# - API Documentation: https://api-sports.io/documentation/nba/v2

# %%
import requests

url = "https://google-translate1.p.rapidapi.com/language/translate/v2"

text = input("Enter to translate: ")
text2 = input("language to translate into (examples: es): ")
data = {'q':text, 'target':text2}
headers = {
	"content-type": "application/x-www-form-urlencoded",
	"Accept-Encoding": "application/gzip",
	"X-RapidAPI-Key": "278u8ud8wy*(&WA*(DS*(H@*(Y89uwu", #key hidden for secrecy,
	"X-RapidAPI-Host": "google-translate1.p.rapidapi.com"
}

response = requests.request("POST", url, data=data, headers=headers)

print(f"translated {text} with {text2}")
print(response.text)
js = response.json()
print(f"Text: {js['data']['translations'][0]['translatedText']}")
# Out:
# translated Hello my name is world. I am 30 years old with es
# {"data":{"translations":[{"translatedText":"Hola mi nombre es mundo. tengo 30 años de edad","detectedSourceLanguage":"en"}]}}
# Text: Hola mi nombre es mundo. tengo 30 años de edad

# %% [markdown]
# ![Screen%20Shot%202022-10-07%20at%202.05.50%20PM.png](attachment:Screen%20Shot%202022-10-07%20at%202.05.50%20PM.png)
